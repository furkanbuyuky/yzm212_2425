# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

data = pd.read_csv("student_scores.csv")

X = data[['Hours']].values
y = data['Scores'].values

model = LinearRegression()
model.fit(X, y)

m = model.coef_[0]
b = model.intercept_

y_pred = model.predict(X)
cost = mean_squared_error(y, y_pred)

print(f"m: {m:.4f}")
print(f"b: {b:.4f}")
print(f"Cost: {cost:.4f}")

plt.scatter(data['Hours'], data['Scores'], color='black', label='Veri Noktaları')
x_vals = np.linspace(data['Hours'].min(), data['Hours'].max(), 100)
y_vals = m * x_vals + b
plt.plot(x_vals, y_vals, color='red', label='Doğrusal Model')
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.legend()
plt.show()
# Out:
# m: 9.7758
# b: 2.4837
# Cost: 28.8827
